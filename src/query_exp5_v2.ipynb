# %%
# !pip install pyTigerGraph -q

# %%
import pandas as pd
import numpy as np
import pyTigerGraph as tg
import json

# %%
# connection parameters
# hostName is the TigerGraph solution URL
hostName = "https://lcp-313-1.i.tgcloud.io/"
graphName = "exp5"
userName = "tigergraph"
password = "tigergraph"

# establish the connection to the TigerGraph Solution
conn = tg.TigerGraphConnection(host=hostName, username=userName, password=password)

# set the name of the graph that we want to connect to
conn.graphname = graphName

# create a secret
secret = conn.createSecret()
# use the secret to get a token
authToken = conn.getToken(secret)[0]

# connect to graph with token
conn = tg.TigerGraphConnection(host=hostName, username=userName, password=password, graphname=graphName, apiToken=authToken)

# %% [markdown]
# ## EXPLORATION

# %%
results = conn.getVertexTypes()
print(f"Verticies: {results}")
vertices = results

results = conn.getEdgeTypes()
print(f"Edges: {results}")
edges = results
# Out:
# Verticies: ['docs', 'sdg', 'sentiment', 'continents']
# Edges: ['has_sdg', 'has_sentiment', 'has_continent']

# %%
print(f"Results for docs vertex")
print(conn.getVertexType("docs"))

print("-----------------")
print(f"Results for has_sdg edge")
print(conn.getEdgeType("has_sdg"))
# Out:
# Results for docs vertex
# {'Config': {'TAGGABLE': False, 'STATS': 'OUTDEGREE_BY_EDGETYPE', 'PRIMARY_ID_AS_ATTRIBUTE': True}, 'IsLocal': True, 'Attributes': [{'AttributeType': {'Name': 'INT'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': False, 'AttributeName': 'page', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}, {'AttributeType': {'Name': 'STRING'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': False, 'AttributeName': 'txt', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}], 'PrimaryId': {'AttributeType': {'Name': 'INT'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': True, 'AttributeName': 'id', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}, 'Name': 'docs'}
# -----------------
# Results for has_sdg edge
# {'IsDirected': True, 'ToVertexTypeName': 'sdg', 'Config': {'REVERSE_EDGE': 'reverse_has_sdg'}, 'IsLocal': True, 'Attributes': [{'AttributeType': {'Name': 'INT'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': False, 'AttributeName': 'docid', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}, {'AttributeType': {'Name': 'INT'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': False, 'AttributeName': 'sdgid', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}, {'AttributeType': {'Name': 'STRING'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': False, 'AttributeName': 'sdg', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}, {'AttributeType': {'Name': 'INT'}, 'IsPartOfCompositeKey': False, 'PrimaryIdAsAttribute': False, 'AttributeName': 'weight', 'HasIndex': False, 'internalAttribute': False, 'IsPrimaryKey': False}], 'FromVertexTypeName': 'docs', 'Name': 'has_sdg'}

# %%
print("Vertex Counts")
for vertex in vertices:
  print(f"There are {conn.getVertexCount(vertex)} {vertex} vertices in the graph")

print("--------------")
print("Edge Counts")
for edge in edges:
  print(f"There are {conn.getEdgeCount(edge)} {edge} edges in the graph")
  #this is now correct in exp5
# Out:
# Vertex Counts
# There are 10 docs vertices in the graph
# There are 16 sdg vertices in the graph
# There are 8 sentiment vertices in the graph
# There are 9 continents vertices in the graph
# --------------
# Edge Counts
# There are 98 has_sdg edges in the graph
# There are 72 has_sentiment edges in the graph
# There are 44 has_continent edges in the graph

# %%
#df1 = conn.getVertexDataframe("orgs")   #didn't all orgs to exp5 yet
#print(df1)

# %%
df2 = conn.getVertexDataframe("sdg")
print(df2)
#this is now correct in exp5
# Out:
#    v_id  id          sdga
# 0    12  12   consumption
# 1     7   7        energy
# 2     3   3        health
# 3     4   4     education
# 4     5   5        gender
# 5     1   1       poverty
# 6     6   6         clean
# 7    16  16         peace
# 8     8   8          work
# 9     2   2        hunger
# 10    9   9      industry
# 11   10  10  inequalities
# 12   15  15          land
# 13   13  13       climate
# 14   11  11        cities
# 15   14  14         water

# %%
df3 = conn.getVertexDataframe("docs")
print(df3)
#is this correct? - where is txt contents for each page?
# Out:
#   v_id  id  page                                                txt
# 0    7   7    68  The Sustainable Development Goals are more imp...
# 1    3   3    52  working for a just world that values and conse...
# 2    4   4    52  working for a just world that values and conse...
# 3    5   5    68  <U+202B><U+0623><U+0635><U+0628><U+062D><U+062...
# 4    1   1    52  WORKING FOR A JUST WORLD THAT VALUES AND CONSE...
# 5    6   6    68  Les objectifs de d<e9>veloppement durable sont...
# 6    8   8  3920  Final Government Distribution Glossary IPCC AR...
# 7    2   2    52  working for a just world that values and conse...
# 8    9   9     2  C Climate Information for Risk Assessment and ...
# 9   10  10    40                                                 NA

# %%
df4 = conn.getVertexDataframe("sentiment")
print(df4)
#this is now correct in exp5
# Out:
#   v_id  id         senti
# 0    7   7      surprise
# 1    3   3       disgust
# 2    4   4          fear
# 3    5   5           joy
# 4    6   6       sadness
# 5    1   1         anger
# 6    8   8         trust
# 7    2   2  anticipation

# %%
df5 = conn.getVertexDataframe("continents")
print(df5)
#this is now correct in exp5
# Out:
#   v_id  id           cont
# 0    7   7  north america
# 1    3   3     antarctica
# 2    4   4      australia
# 3    5   5         europe
# 4    6   6        america
# 5    1   1         africa
# 6    8   8  south america
# 7    2   2           asia
# 8    9   9        oceania

# %% [markdown]
# ## TRY SOME QUERIES

# %%
results = conn.getVerticesById("docs", "1")
print(results)
# Out:
# [{'v_id': '1', 'v_type': 'docs', 'attributes': {'id': 1, 'page': 52, 'txt': '"WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'}}]

# %%
results = conn.getVerticesById("docs", ["1", "9"])
print(results)
# Out:
# [{'v_id': '1', 'v_type': 'docs', 'attributes': {'id': 1, 'page': 52, 'txt': '"WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'}}, {'v_id': '9', 'v_type': 'docs', 'attributes': {'id': 9, 'page': 2, 'txt': '"C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence"'}}]

# %%
results = conn.getEdgeCountFrom("docs", "1")
print(results)
# Out:
# {'has_sdg': 14, 'reverse_has_sdg': 0, 'has_sentiment': 8, 'reverse_has_sentiment': 0, 'has_continent': 6, 'reverse_has_continent': 0}

# %%
results = conn.getEdgeCountFrom("sdg", "1")
print(results)
# Out:
# {'has_sdg': 0, 'reverse_has_sdg': 6, 'has_sentiment': 0, 'reverse_has_sentiment': 0, 'has_continent': 0, 'reverse_has_continent': 0}

# %% [markdown]
# ---------------------------
# ------------------------------------------
# ----------------------------

# %%
conn.gsql("""
USE GRAPH exp5
CREATE QUERY test_query() FOR GRAPH exp5 {
    PRINT "Hello World";
}
""")

conn.gsql("""
USE GRAPH exp5
INSTALL QUERY test_query
""")
# Out:
# 'Using graph \'exp5\'\nStart installing queries, about 1 minute ...\ntest_query query: curl -X GET \'https://127.0.0.1:9000/query/exp5/test_query\'. Add -H "Authorization: Bearer TOKEN" if authentication is enabled.\nSelect \'m1\' as compile server, now connecting ...\nNode \'m1\' is prepared as compile server.\n\nQuery installation finished.'

# %%
conn.runInstalledQuery("test_query")
# Out:
# [{'"Hello World"': 'Hello World'}]

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY interpret_query() FOR GRAPH exp5 {
    PRINT "Hello World" AS Output;
}
""")
#this works as interpreted query, revisit below
# Out:
# [{'Output': 'Hello World'}]

# %% [markdown]
# ### Official sdg query

# %%
conn.gsql("""
USE GRAPH exp5
CREATE QUERY sdg_general() FOR GRAPH exp5 {
  start = {sdg.*};
  result = SELECT s from start:s;
  PRINT result;
}
""")

conn.gsql("""
USE GRAPH exp5
INSTALL QUERY sdg_general
""")
# Out:
# 'Using graph \'exp5\'\nStart installing queries, about 1 minute ...\nsdg_general query: curl -X GET \'https://127.0.0.1:9000/query/exp5/sdg_general\'. Add -H "Authorization: Bearer TOKEN" if authentication is enabled.\nSelect \'m1\' as compile server, now connecting ...\nNode \'m1\' is prepared as compile server.\n\nQuery installation finished.'

# %%
conn.runInstalledQuery("sdg_general")
# Out:
# [{'result': [{'attributes': {'id': 14, 'sdga': 'water'},
#     'v_id': '14',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 11, 'sdga': 'cities'}, 'v_id': '11', 'v_type': 'sdg'},
#    {'attributes': {'id': 15, 'sdga': 'land'}, 'v_id': '15', 'v_type': 'sdg'},
#    {'attributes': {'id': 10, 'sdga': 'inequalities'},
#     'v_id': '10',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 9, 'sdga': 'industry'}, 'v_id': '9', 'v_type': 'sdg'},
#    {'attributes': {'id': 2, 'sdga': 'hunger'}, 'v_id': '2', 'v_type': 'sdg'},
#    {'attributes': {'id': 16, 'sdga': 'peace'}, 'v_id': '16', 'v_type': 'sdg'},
#    {'attributes': {'id': 8, 'sdga': 'work'}, 'v_id': '8', 'v_type': 'sdg'},
#    {'attributes': {'id': 1, 'sdga': 'poverty'}, 'v_id': '1', 'v_type': 'sdg'},
#    {'attributes': {'id': 6, 'sdga': 'clean'}, 'v_id': '6', 'v_type': 'sdg'},
#    {'attributes': {'id': 5, 'sdga': 'gender'}, 'v_id': '5', 'v_type': 'sdg'},
#    {'attributes': {'id': 4, 'sdga': 'education'},
#     'v_id': '4',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 3, 'sdga': 'health'}, 'v_id': '3', 'v_type': 'sdg'},
#    {'attributes': {'id': 12, 'sdga': 'consumption'},
#     'v_id': '12',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 7, 'sdga': 'energy'}, 'v_id': '7', 'v_type': 'sdg'},
#    {'attributes': {'id': 13, 'sdga': 'climate'},
#     'v_id': '13',
#     'v_type': 'sdg'}]}]

# %% [markdown]
# ### Official docs query

# %%
conn.gsql("""
USE GRAPH exp5
CREATE QUERY docs_general() FOR GRAPH exp5 {
  start = {docs.*};
  result = SELECT s from start:s;
  PRINT result;
}
""")

conn.gsql("""
USE GRAPH exp5
INSTALL QUERY docs_general
""")
# Out:
# 'Using graph \'exp5\'\nStart installing queries, about 1 minute ...\ndocs_general query: curl -X GET \'https://127.0.0.1:9000/query/exp5/docs_general\'. Add -H "Authorization: Bearer TOKEN" if authentication is enabled.\nSelect \'m1\' as compile server, now connecting ...\nNode \'m1\' is prepared as compile server.\n\nQuery installation finished.'

# %%
conn.runInstalledQuery("docs_general")
# Out:
# [{'result': [{'attributes': {'id': 10, 'page': 40, 'txt': 'NA'},
#     'v_id': '10',
#     'v_type': 'docs'},
#    {'attributes': {'id': 2,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '2',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3949,
#      'txt': '"Final Government Distribution Glossary IPCC AR6 WGI 1 Model Development 1011 40354055 doi105194gmd1040352017 2 Lempert RJ SW Popper and SC Bankes 2003 Shaping the Next One Hundred Years New Methods for 3 Quantitative LongTerm Policy Analysis RAND Corporation Santa Monica CA USA 186 pp 4 MA 2005 Appendix D Glossary In Ecosystems and Human Wellbeing Current States and Trends Findings of the 5 Condition and Trends Working Group Hassan R R Scholes and N Ash eds Millennium Ecosystem 6 Assessment MEA Island Press Washington DC USA pp 893900 7 Mastrandrea MD et al 2010 Guidance Note for Lead Authors of the IPCC Fifth Assessment Report on Consistent 8 Treatment of Uncertainties Intergovernmental Panel on Climate Change IPCC Geneva Switzerland 6 pp 9 Mix AC WF Ruddiman and A McIntyre 1986 Late Quaternary paleoceanography of the Tropical Atlantic 1 10 Spatial variability of annual mean seasurface temperatures 020000 years BP Paleoceanography 11 43 11 66 doi101029pa001i001p00043 12 Mix AC E Bard and R Schneider 2001 Environmental processes of the ice age land oceans glaciers EPILOG 13 Quaternary Science Reviews 204 627657 doi101016s0277379100001451 14 Moss RH and SH Schneider 2000 Uncertainties in the IPCC TAR Recommendations to Lead Authors for More 15 Consistent Assessment and Reporting In Guidance Papers on the Cross Cutting Issues of the Third 16 ED N Assessment Report of the IPCC Pachauri R T Taniguchi and K Tanaka eds Intergovernmental Panel on S 17 Climate Change IPCC Geneva Switzerland pp 3351 18 Moss RH et al 2010 The next generation of scenarios for climate change research and assessment Nature IT AL IO 19 4637282 747756 doi101038nature08823 20 NOAA 2021 What is an iceberg National Oceanic and Atmospheric Administration NOAA National Ocean 21 Service website Retrieved from httpsoceanservicenoaagovfactsiceberghtml N S 22 Pongratz J et al 2018 Models meet data Challenges and opportunities in implementing land management in Earth 23 system models Global Change Biology 244 14701487 doi101111gcb13988 24 25 FI R Ralph FM MD Dettinger MM Cairns TJ Galarneau and J Eylander 2018 Defining Atmospheric River How the Glossary of Meteorology Helped Resolve a Debate Bulletin of the American Meteorological Society VE 26 994 837839 doi101175bamsd1701571 27 Schwartz SE and P Warneck 1995 Units for use in atmospheric chemistry IUPAC Recommendations 1995 Pure 28 and Applied Chemistry 6789 13771406 29 Shepherd TG et al 2018 Storylines an alternative approach to representing uncertainty in physical aspects of 30 climate change Climatic Change 15134 555571 doi101007s1058401823179 TO D 31 Stocker TF and SJ Johnsen 2003 A minimum thermodynamic model for the bipolar seesaw Paleoceanography 32 184 doi1010292003pa000920 33 T<fc>rkes M 1999 Vulnerability of Turkey to Desertification With Respect to Precipitation and Aridity Conditions T E 34 Turkish Journal of Engineering and Environmental Sciences 23 363380 35 UNCCD 1994 United Nations Convention to Combat Desertification in countries experiencing serious drought andor T 36 desertification particularly in Africa 58 pp 37 UNESCOIASHWMO 1970 Seasonal snow cover A guide for measurement compilation and assemblage of data EC P 38 United Nations Educational Scientific and Cultural Organization UNESCO Paris France 38 pp 39 UNFCCC 1992 United Nations Framework Convention on Climate Change FCCCINFORMAL84 United Nations BJ CE 40 Framework Convention on Climate Change UNFCCC 24 pp 41 UNFCCC 2021a Reporting and accounting of LULUCF activities under the Kyoto Protocol United Nations 42 Framework Convention on Climate Change UNFCCC Retrieved from httpsunfcccinttopicsland 43 useworkstreamslanduselandusechangeandforestrylulucfreportingandaccountingoflulucfactivities SU AC 44 underthekyotoprotocol 45 UNFCCC 2021b Reporting and Review under the Paris Agreement United Nations Framework Convention on 46 Climate Change UNFCCC Retrieved from httpsunfcccintprocessandmeetingstransparencyand 47 reportingreportingand ...
#     'v_id': '8',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': '"WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 6,
#      'page': 68,
#      'txt': '"Les objectifs de d<e9>veloppement durable sont aujourdhui plus importants que jamais Le temps est <e0> pr<e9>sent venu dassurer le bien <ea>tre des peuples des <e9>conomies des soci<e9>t<e9>s et de notre plan<e8>te Ant<f3>nio GUTERRES Secr<e9>taire g<e9>n<e9>ral de lONU 2104310"'},
#     'v_id': '6',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '"<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>"'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '3',
#     'v_type': 'docs'},
#    {'attributes': {'id': 7,
#      'page': 68,
#      'txt': '"The Sustainable Development Goals are more important now than ever Now is the time to secure the wellbeing of people economies societies and our planet Ant<f3>nio GUTERRES SecretaryGeneral of the United Nations ISBN 9789211014396 2104310"'},
#     'v_id': '7',
#     'v_type': 'docs'},
#    {'attributes': {'id': 9,
#      'page': 2,
#      'txt': '"C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence"'},
#     'v_id': '9',
#     'v_type': 'docs'}]}]

# %% [markdown]
# ### Official sentiment query

# %%
conn.gsql("""
USE GRAPH exp5
CREATE QUERY sentiment_all() FOR GRAPH exp5 {
  start = {sentiment.*};
  result = SELECT s from start:s;
  PRINT result;
}
""")

conn.gsql("""
USE GRAPH exp5
INSTALL QUERY sentiment_all
""")
# Out:
# 'Using graph \'exp5\'\nStart installing queries, about 1 minute ...\nsentiment_all query: curl -X GET \'https://127.0.0.1:9000/query/exp5/sentiment_all\'. Add -H "Authorization: Bearer TOKEN" if authentication is enabled.\nSelect \'m1\' as compile server, now connecting ...\nNode \'m1\' is prepared as compile server.\n\nQuery installation finished.'

# %%
conn.runInstalledQuery("sentiment_all")
# Out:
# [{'result': [{'attributes': {'id': 2, 'senti': 'anticipation'},
#     'v_id': '2',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 6, 'senti': 'sadness'},
#     'v_id': '6',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 1, 'senti': 'anger'},
#     'v_id': '1',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 5, 'senti': 'joy'},
#     'v_id': '5',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 4, 'senti': 'fear'},
#     'v_id': '4',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 3, 'senti': 'disgust'},
#     'v_id': '3',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 7, 'senti': 'surprise'},
#     'v_id': '7',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 8, 'senti': 'trust'},
#     'v_id': '8',
#     'v_type': 'sentiment'}]}]

# %% [markdown]
# ### TRY TO GET AN INTERPRETED QUERY WORKING

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY junk_query() FOR GRAPH exp5 {
    PRINT "Hello World" AS Output;
    // this is a junk query

}
""")
#this works as interpreted query
# Out:
# [{'Output': 'Hello World'}]

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY junk() FOR GRAPH exp5 {
    start = {sdg.*};
    result = SELECT s from start:s;
    PRINT result;
}
""")
#wow it works now, i guess i can't call something "sample"
# Out:
# [{'result': [{'attributes': {'id': 14, 'sdga': 'water'},
#     'v_id': '14',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 11, 'sdga': 'cities'}, 'v_id': '11', 'v_type': 'sdg'},
#    {'attributes': {'id': 13, 'sdga': 'climate'},
#     'v_id': '13',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 15, 'sdga': 'land'}, 'v_id': '15', 'v_type': 'sdg'},
#    {'attributes': {'id': 10, 'sdga': 'inequalities'},
#     'v_id': '10',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 9, 'sdga': 'industry'}, 'v_id': '9', 'v_type': 'sdg'},
#    {'attributes': {'id': 2, 'sdga': 'hunger'}, 'v_id': '2', 'v_type': 'sdg'},
#    {'attributes': {'id': 16, 'sdga': 'peace'}, 'v_id': '16', 'v_type': 'sdg'},
#    {'attributes': {'id': 8, 'sdga': 'work'}, 'v_id': '8', 'v_type': 'sdg'},
#    {'attributes': {'id': 1, 'sdga': 'poverty'}, 'v_id': '1', 'v_type': 'sdg'},
#    {'attributes': {'id': 6, 'sdga': 'clean'}, 'v_id': '6', 'v_type': 'sdg'},
#    {'attributes': {'id': 5, 'sdga': 'gender'}, 'v_id': '5', 'v_type': 'sdg'},
#    {'attributes': {'id': 4, 'sdga': 'education'},
#     'v_id': '4',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 3, 'sdga': 'health'}, 'v_id': '3', 'v_type': 'sdg'},
#    {'attributes': {'id': 12, 'sdga': 'consumption'},
#     'v_id': '12',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 7, 'sdga': 'energy'}, 'v_id': '7', 'v_type': 'sdg'}]}]

# %% [markdown]
# ## TRY SOME USEFUL QUERIES for CONNECTIONS

# %% [markdown]
# #### example1... find all "clean" sdg vertices (#6) are connected to which docs  docs (need to traverse clean to docs)   - [should result in doc1,3,4,5,8,9]

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc() FOR GRAPH exp5 {
    start = {sdg.*};
    result = SELECT d FROM start:s  - () - docs:d WHERE s.sdga == "clean";
    PRINT result;
    
}
""")
#works!! (found 1,3,4,6,8,9)
#now try to install and view it?
# Out:
# [{'result': [{'attributes': {'id': 9,
#      'page': 2,
#      'txt': '"C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence"'},
#     'v_id': '9',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3949,
#      'txt': '"Final Government Distribution Glossary IPCC AR6 WGI 1 Model Development 1011 40354055 doi105194gmd1040352017 2 Lempert RJ SW Popper and SC Bankes 2003 Shaping the Next One Hundred Years New Methods for 3 Quantitative LongTerm Policy Analysis RAND Corporation Santa Monica CA USA 186 pp 4 MA 2005 Appendix D Glossary In Ecosystems and Human Wellbeing Current States and Trends Findings of the 5 Condition and Trends Working Group Hassan R R Scholes and N Ash eds Millennium Ecosystem 6 Assessment MEA Island Press Washington DC USA pp 893900 7 Mastrandrea MD et al 2010 Guidance Note for Lead Authors of the IPCC Fifth Assessment Report on Consistent 8 Treatment of Uncertainties Intergovernmental Panel on Climate Change IPCC Geneva Switzerland 6 pp 9 Mix AC WF Ruddiman and A McIntyre 1986 Late Quaternary paleoceanography of the Tropical Atlantic 1 10 Spatial variability of annual mean seasurface temperatures 020000 years BP Paleoceanography 11 43 11 66 doi101029pa001i001p00043 12 Mix AC E Bard and R Schneider 2001 Environmental processes of the ice age land oceans glaciers EPILOG 13 Quaternary Science Reviews 204 627657 doi101016s0277379100001451 14 Moss RH and SH Schneider 2000 Uncertainties in the IPCC TAR Recommendations to Lead Authors for More 15 Consistent Assessment and Reporting In Guidance Papers on the Cross Cutting Issues of the Third 16 ED N Assessment Report of the IPCC Pachauri R T Taniguchi and K Tanaka eds Intergovernmental Panel on S 17 Climate Change IPCC Geneva Switzerland pp 3351 18 Moss RH et al 2010 The next generation of scenarios for climate change research and assessment Nature IT AL IO 19 4637282 747756 doi101038nature08823 20 NOAA 2021 What is an iceberg National Oceanic and Atmospheric Administration NOAA National Ocean 21 Service website Retrieved from httpsoceanservicenoaagovfactsiceberghtml N S 22 Pongratz J et al 2018 Models meet data Challenges and opportunities in implementing land management in Earth 23 system models Global Change Biology 244 14701487 doi101111gcb13988 24 25 FI R Ralph FM MD Dettinger MM Cairns TJ Galarneau and J Eylander 2018 Defining Atmospheric River How the Glossary of Meteorology Helped Resolve a Debate Bulletin of the American Meteorological Society VE 26 994 837839 doi101175bamsd1701571 27 Schwartz SE and P Warneck 1995 Units for use in atmospheric chemistry IUPAC Recommendations 1995 Pure 28 and Applied Chemistry 6789 13771406 29 Shepherd TG et al 2018 Storylines an alternative approach to representing uncertainty in physical aspects of 30 climate change Climatic Change 15134 555571 doi101007s1058401823179 TO D 31 Stocker TF and SJ Johnsen 2003 A minimum thermodynamic model for the bipolar seesaw Paleoceanography 32 184 doi1010292003pa000920 33 T<fc>rkes M 1999 Vulnerability of Turkey to Desertification With Respect to Precipitation and Aridity Conditions T E 34 Turkish Journal of Engineering and Environmental Sciences 23 363380 35 UNCCD 1994 United Nations Convention to Combat Desertification in countries experiencing serious drought andor T 36 desertification particularly in Africa 58 pp 37 UNESCOIASHWMO 1970 Seasonal snow cover A guide for measurement compilation and assemblage of data EC P 38 United Nations Educational Scientific and Cultural Organization UNESCO Paris France 38 pp 39 UNFCCC 1992 United Nations Framework Convention on Climate Change FCCCINFORMAL84 United Nations BJ CE 40 Framework Convention on Climate Change UNFCCC 24 pp 41 UNFCCC 2021a Reporting and accounting of LULUCF activities under the Kyoto Protocol United Nations 42 Framework Convention on Climate Change UNFCCC Retrieved from httpsunfcccinttopicsland 43 useworkstreamslanduselandusechangeandforestrylulucfreportingandaccountingoflulucfactivities SU AC 44 underthekyotoprotocol 45 UNFCCC 2021b Reporting and Review under the Paris Agreement United Nations Framework Convention on 46 Climate Change UNFCCC Retrieved from httpsunfcccintprocessandmeetingstransparencyand 47 reportingreportingand ...
#     'v_id': '8',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': '"WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '"<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>"'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '3',
#     'v_type': 'docs'}]}]

# %%
conn.gsql("""
USE GRAPH exp5
CREATE QUERY sdg_todoc() FOR GRAPH exp5 {
    start = {sdg.*};
    result = SELECT d FROM start:s  - () - docs:d WHERE s.sdga == "clean";
    PRINT result;
}
""")

conn.gsql("""
USE GRAPH exp5
INSTALL QUERY sdg_todoc
""")
# Out:
# "Using graph 'exp5'\nSemantic Check Fails: Graph exp5: all queries in this catalog have been installed already.\nQuery installation finished."

# %%
##DROP/UNINSTALL COMMAND BLOCK, IF NEEDED

#conn.gsql("""
#USE GRAPH exp5
#DROP QUERY sdg_todoc
#""")

# %%
conn.runInstalledQuery("sdg_todoc")
#works!!!
# Out:
# [{'result': [{'attributes': {'id': 9,
#      'page': 2,
#      'txt': '"C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence"'},
#     'v_id': '9',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': '"WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '"<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>"'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': '"working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg"'},
#     'v_id': '3',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3949,
#      'txt': '"Final Government Distribution Glossary IPCC AR6 WGI 1 Model Development 1011 40354055 doi105194gmd1040352017 2 Lempert RJ SW Popper and SC Bankes 2003 Shaping the Next One Hundred Years New Methods for 3 Quantitative LongTerm Policy Analysis RAND Corporation Santa Monica CA USA 186 pp 4 MA 2005 Appendix D Glossary In Ecosystems and Human Wellbeing Current States and Trends Findings of the 5 Condition and Trends Working Group Hassan R R Scholes and N Ash eds Millennium Ecosystem 6 Assessment MEA Island Press Washington DC USA pp 893900 7 Mastrandrea MD et al 2010 Guidance Note for Lead Authors of the IPCC Fifth Assessment Report on Consistent 8 Treatment of Uncertainties Intergovernmental Panel on Climate Change IPCC Geneva Switzerland 6 pp 9 Mix AC WF Ruddiman and A McIntyre 1986 Late Quaternary paleoceanography of the Tropical Atlantic 1 10 Spatial variability of annual mean seasurface temperatures 020000 years BP Paleoceanography 11 43 11 66 doi101029pa001i001p00043 12 Mix AC E Bard and R Schneider 2001 Environmental processes of the ice age land oceans glaciers EPILOG 13 Quaternary Science Reviews 204 627657 doi101016s0277379100001451 14 Moss RH and SH Schneider 2000 Uncertainties in the IPCC TAR Recommendations to Lead Authors for More 15 Consistent Assessment and Reporting In Guidance Papers on the Cross Cutting Issues of the Third 16 ED N Assessment Report of the IPCC Pachauri R T Taniguchi and K Tanaka eds Intergovernmental Panel on S 17 Climate Change IPCC Geneva Switzerland pp 3351 18 Moss RH et al 2010 The next generation of scenarios for climate change research and assessment Nature IT AL IO 19 4637282 747756 doi101038nature08823 20 NOAA 2021 What is an iceberg National Oceanic and Atmospheric Administration NOAA National Ocean 21 Service website Retrieved from httpsoceanservicenoaagovfactsiceberghtml N S 22 Pongratz J et al 2018 Models meet data Challenges and opportunities in implementing land management in Earth 23 system models Global Change Biology 244 14701487 doi101111gcb13988 24 25 FI R Ralph FM MD Dettinger MM Cairns TJ Galarneau and J Eylander 2018 Defining Atmospheric River How the Glossary of Meteorology Helped Resolve a Debate Bulletin of the American Meteorological Society VE 26 994 837839 doi101175bamsd1701571 27 Schwartz SE and P Warneck 1995 Units for use in atmospheric chemistry IUPAC Recommendations 1995 Pure 28 and Applied Chemistry 6789 13771406 29 Shepherd TG et al 2018 Storylines an alternative approach to representing uncertainty in physical aspects of 30 climate change Climatic Change 15134 555571 doi101007s1058401823179 TO D 31 Stocker TF and SJ Johnsen 2003 A minimum thermodynamic model for the bipolar seesaw Paleoceanography 32 184 doi1010292003pa000920 33 T<fc>rkes M 1999 Vulnerability of Turkey to Desertification With Respect to Precipitation and Aridity Conditions T E 34 Turkish Journal of Engineering and Environmental Sciences 23 363380 35 UNCCD 1994 United Nations Convention to Combat Desertification in countries experiencing serious drought andor T 36 desertification particularly in Africa 58 pp 37 UNESCOIASHWMO 1970 Seasonal snow cover A guide for measurement compilation and assemblage of data EC P 38 United Nations Educational Scientific and Cultural Organization UNESCO Paris France 38 pp 39 UNFCCC 1992 United Nations Framework Convention on Climate Change FCCCINFORMAL84 United Nations BJ CE 40 Framework Convention on Climate Change UNFCCC 24 pp 41 UNFCCC 2021a Reporting and accounting of LULUCF activities under the Kyoto Protocol United Nations 42 Framework Convention on Climate Change UNFCCC Retrieved from httpsunfcccinttopicsland 43 useworkstreamslanduselandusechangeandforestrylulucfreportingandaccountingoflulucfactivities SU AC 44 underthekyotoprotocol 45 UNFCCC 2021b Reporting and Review under the Paris Agreement United Nations Framework Convention on 46 Climate Change UNFCCC Retrieved from httpsunfcccintprocessandmeetingstransparencyand 47 reportingreportingand ...
#     'v_id': '8',
#     'v_type': 'docs'}]}]

# %%
#now try by adding the reverse_has_sdg, and select s (not d) - it should return that sdg #6 only
conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_() FOR GRAPH exp5 {
    start = {sdg.*};
    result = SELECT s FROM start:s  - (reverse_has_sdg) - docs:d  /*or can leave as () since only 1 edge */
    WHERE s.sdga == "clean" ;
    PRINT result;    
}
""")
#works!
# Out:
# [{'result': [{'attributes': {'id': 6, 'sdga': 'clean'},
#     'v_id': '6',
#     'v_type': 'sdg'}]}]

# %%
#now try summing the number of docs that contain sdg by adding accumulator
conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_sum() FOR GRAPH exp5 {
   
    SumAccum<INT> @@docsum;  /*declare the accumulator here*/

    start = {sdg.*};
    result = SELECT d FROM start:s  - (reverse_has_sdg) - docs:d  /*or can leave as () since only 1 edge */
    WHERE s.sdga == "clean"
    ACCUM 
      @@docsum += 1;
    // PRINT result; 
    PRINT @@docsum AS num_Docs;   
}
""")
#works!!
# Out:
# [{'num_Docs': 6}]

# %%
#install this one...
conn.gsql("""
USE GRAPH exp5
CREATE QUERY sdg_todoc_sum() FOR GRAPH exp5 {
   
    SumAccum<INT> @@docsum;  /*declare the accumulator here*/

    start = {sdg.*};
    result = SELECT d FROM start:s  - (reverse_has_sdg) - docs:d  /*or can leave as () since only 1 edge */
    WHERE s.sdga == "clean"
    ACCUM 
      @@docsum += 1;
    // PRINT result; 
    PRINT @@docsum AS num_Docs;   
}
""")

conn.gsql("""
USE GRAPH exp5
INSTALL QUERY sdg_todoc_sum
""")
# Out:
# "Using graph 'exp5'\nSemantic Check Fails: Graph exp5: all queries in this catalog have been installed already.\nQuery installation finished."

# %%
conn.runInstalledQuery("sdg_todoc_sum")
#cool
# Out:
# [{'num_Docs': 6}]

# %% [markdown]
# #### example2... find all sdg vertices that contain asia (need to traverse back to docs) - 2-hop

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_weight() FOR GRAPH exp5 {
    start = {sdg.*};
    result = SELECT d FROM start:s  - (reverse_has_sdg) - docs:d  
    WHERE s.sdga == "clean" /*HAVING reverse_has_sdg.weight > 1*/;
    PRINT result[0];     //added index [0] ??
}
""")
#continue from here... this is same as example 1 as of 04102022 4pm
#this is junk , just trying the [0] thing
# Out:
# [{'result': [{'attributes': {'0': 0}, 'v_id': '1', 'v_type': 'docs'},
#    {'attributes': {'0': 0}, 'v_id': '8', 'v_type': 'docs'},
#    {'attributes': {'0': 0}, 'v_id': '4', 'v_type': 'docs'},
#    {'attributes': {'0': 0}, 'v_id': '3', 'v_type': 'docs'},
#    {'attributes': {'0': 0}, 'v_id': '5', 'v_type': 'docs'},
#    {'attributes': {'0': 0}, 'v_id': '9', 'v_type': 'docs'}]}]

# %%
#single hop sdg
inputName = "clean"

conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_generic(STRING inName) FOR GRAPH exp5 {
    start = {sdg.*};
    result = SELECT d FROM start:s  - () - docs:d WHERE s.sdga == inName;
    PRINT result;  
}
""",
    params={ "inName": inputName }
)
# Out:
# [{'result': [{'attributes': {'id': 9,
#      'page': 2,
#      'txt': 'C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence'},
#     'v_id': '9',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3920,
#      'txt': 'Final Government Distribution Glossary IPCC AR6 WGI 1 2 Latent heat flux The turbulent flux of heat from the Earths surface to the atmosphere that is associated 3 with evaporation or condensation of water vapour at the surface a component of the surface energy budget 4 See also Atmosphere and Flux 5 6 Lifetime Lifetime is a general term used for various time scales characterizing the rate of processes 7 affecting the concentration of trace gases The following lifetimes may be distinguished 8 9 Response time or adjustment time Ta Response time or adjustment time Ta is the time scale 10 characterizing the decay of an instantaneous pulse input into the reservoir The term adjustment time is also 11 used to characterize the adjustment of the mass of a reservoir following a step change in the source strength 12 Halflife or decay constant is used to quantify a firstorder exponential decay process See Response time or 13 adjustment time for a different definition pertinent to climate variations 14 ED N S 15 The term lifetime is sometimes used for simplicity as a surrogate for adjustment time 16 IT AL IO 17 In simple cases where the global removal of the compound is directly proportional to the total mass of the 18 reservoir the adjustment time equals the turnover time T = Ta An example is CFC11 which is removed 19 from the atmosphere only by photochemical processes in the stratosphere In more complicated cases where N S 20 several reservoirs are involved or where the removal is not proportional to the total mass the equality T = Ta 21 no longer holds 22 23 FI R Carbon dioxide CO2 is an extreme example Its turnover time is only about 4 years because of the rapid VE 24 exchange between the atmosphere and the ocean and terrestrial biota However a large part of that CO2 is 25 returned to the atmosphere within a few years The adjustment time of CO2 in the atmosphere is determined 26 from the rates of removal of carbon by a range of processes with timescales from months to hundreds of 27 thousands of years As a result 15 to 40 of an emitted CO2 pulse will remain in the atmosphere longer than 28 1000 years 10 to 25 will remain about ten thousand years and the rest will be removed over several TO D 29 hundred thousand years 30 T E 31 In the case of methane CH4 the adjustment time is different from the turnover time because the removal is 32 mainly through a chemical reaction with the hydroxyl radical OH the concentration of which itself T 33 depends on the CH4 concentration Therefore the CH4 removal rate S is not proportional to its total mass M EC P 34 35 Turnover time T also called global atmospheric lifetime is the ratio of the mass M of a reservoir eg a BJ CE 36 gaseous compound in the atmosphere and the total rate of removal S from the reservoir T = MS For each 37 removal process separate turnover times can be defined In soil carbon biology this is referred to as Mean 38 Residence Time 39 SU AC 40 Lightabsorbing particles Lightabsorbing particles LAP eg black carbon brown carbon dust are 41 particles that absorb solar radiation and convert it into internal energy thus raising the particles temperature 42 and emitting thermalinfrared radiation that is selectively absorbed by the surrounding medium LAP affect 43 the energy balance of the atmosphere clouds and when deposited on snow and ice they reduce snowice 44 albedo increasing heating and accelerating smelting These particles have a warming effect on climate 45 46 Likelihood The chance of a specific outcome occurring where this might be estimated probabilistically 47 Likelihood is expressed in this report using a standard terminology Mastrandrea et al 2010 See also 48 Agreement Confidence Evidence and Uncertainty 49 50 Lithosphere The upper layer of the solid Earth both continental and oceanic which comprises all crustal 51 rocks and the cold mainly elastic part of the uppermost mantle Volcanic activity although part of the 52 lithosphere is not considered as part of the cl ...
#     'v_id': '8',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': 'WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '3',
#     'v_type': 'docs'}]}]

# %%
#single hope continent
inputName = "asia"

conn.runInterpretedQuery("""
INTERPRET QUERY cont_todoc_generic(STRING inName) FOR GRAPH exp5 {
    start = {continents.*};
    result = SELECT d FROM start:s  - () - docs:d WHERE s.cont == inName;
    PRINT result;  
}
""",
    params={ "inName": inputName }
)
# Out:
# [{'result': [{'attributes': {'id': 10, 'page': 40, 'txt': 'NA'},
#     'v_id': '10',
#     'v_type': 'docs'},
#    {'attributes': {'id': 2,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '2',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3920,
#      'txt': 'Final Government Distribution Glossary IPCC AR6 WGI 1 2 Latent heat flux The turbulent flux of heat from the Earths surface to the atmosphere that is associated 3 with evaporation or condensation of water vapour at the surface a component of the surface energy budget 4 See also Atmosphere and Flux 5 6 Lifetime Lifetime is a general term used for various time scales characterizing the rate of processes 7 affecting the concentration of trace gases The following lifetimes may be distinguished 8 9 Response time or adjustment time Ta Response time or adjustment time Ta is the time scale 10 characterizing the decay of an instantaneous pulse input into the reservoir The term adjustment time is also 11 used to characterize the adjustment of the mass of a reservoir following a step change in the source strength 12 Halflife or decay constant is used to quantify a firstorder exponential decay process See Response time or 13 adjustment time for a different definition pertinent to climate variations 14 ED N S 15 The term lifetime is sometimes used for simplicity as a surrogate for adjustment time 16 IT AL IO 17 In simple cases where the global removal of the compound is directly proportional to the total mass of the 18 reservoir the adjustment time equals the turnover time T = Ta An example is CFC11 which is removed 19 from the atmosphere only by photochemical processes in the stratosphere In more complicated cases where N S 20 several reservoirs are involved or where the removal is not proportional to the total mass the equality T = Ta 21 no longer holds 22 23 FI R Carbon dioxide CO2 is an extreme example Its turnover time is only about 4 years because of the rapid VE 24 exchange between the atmosphere and the ocean and terrestrial biota However a large part of that CO2 is 25 returned to the atmosphere within a few years The adjustment time of CO2 in the atmosphere is determined 26 from the rates of removal of carbon by a range of processes with timescales from months to hundreds of 27 thousands of years As a result 15 to 40 of an emitted CO2 pulse will remain in the atmosphere longer than 28 1000 years 10 to 25 will remain about ten thousand years and the rest will be removed over several TO D 29 hundred thousand years 30 T E 31 In the case of methane CH4 the adjustment time is different from the turnover time because the removal is 32 mainly through a chemical reaction with the hydroxyl radical OH the concentration of which itself T 33 depends on the CH4 concentration Therefore the CH4 removal rate S is not proportional to its total mass M EC P 34 35 Turnover time T also called global atmospheric lifetime is the ratio of the mass M of a reservoir eg a BJ CE 36 gaseous compound in the atmosphere and the total rate of removal S from the reservoir T = MS For each 37 removal process separate turnover times can be defined In soil carbon biology this is referred to as Mean 38 Residence Time 39 SU AC 40 Lightabsorbing particles Lightabsorbing particles LAP eg black carbon brown carbon dust are 41 particles that absorb solar radiation and convert it into internal energy thus raising the particles temperature 42 and emitting thermalinfrared radiation that is selectively absorbed by the surrounding medium LAP affect 43 the energy balance of the atmosphere clouds and when deposited on snow and ice they reduce snowice 44 albedo increasing heating and accelerating smelting These particles have a warming effect on climate 45 46 Likelihood The chance of a specific outcome occurring where this might be estimated probabilistically 47 Likelihood is expressed in this report using a standard terminology Mastrandrea et al 2010 See also 48 Agreement Confidence Evidence and Uncertainty 49 50 Lithosphere The upper layer of the solid Earth both continental and oceanic which comprises all crustal 51 rocks and the cold mainly elastic part of the uppermost mantle Volcanic activity although part of the 52 lithosphere is not considered as part of the cl ...
#     'v_id': '8',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': 'WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '3',
#     'v_type': 'docs'}]}]

# %%
#attempt at double-hop
inputName = "clean"

conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_toasia(VERTEX<sdg> inName) FOR GRAPH exp5 SYNTAX v2 {
    
    start = {inName};
    result = SELECT d FROM start:s - () - docs:d - () - continents:c; 
    
    PRINT result;
}
""", 
    params={ "inName": inputName }
)
# Out:
# ---------------------------------------------------------------------------
# TigerGraphException                       Traceback (most recent call last)
# <ipython-input-27-a7a6bac450c5> in <module>()
#      11 }
#      12 """,
# ---> 13     params={ "inName": inputName }
#      14 )
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in runInterpretedQuery(self, queryText, params)
#    1193         """
#    1194         queryText = queryText.replace("$graphname", self.graphname)
# -> 1195         return self._post(self.gsUrl + "/gsqlserver/interpreted_query", data=queryText, params=params, authMode="pwd")
#    1196
#    1197     # Pandas DataFrame support =================================================
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in _post(self, url, authMode, headers, data, resKey, skipCheck, params)
#     220         For argument details, see `_req`.
#     221         """
# --> 222         return self._req("POST", url, authMode, headers, data, resKey, skipCheck, params)
#     223
#     224     def _delete(self, url, authMode="token"):
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in _req(self, method, url, authMode, headers, data, resKey, skipCheck, params)
#     198         res = json.loads(res.text)
#     199         if not skipCheck:
# --> 200             self._errorCheck(res)
#     201         if not resKey:
#     202             if self.debug:
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in _errorCheck(self, res)
#     142         if "error" in res and res["error"] and res["error"] != "false":
#     143             # Endpoint might return string "false" rather than Boolean false
# --> 144             raise TigerGraphException(res["message"], (res["code"] if "code" in res else None))
#     145
#     146     def _req(self, method, url, authMode="token", headers=None, data=None, resKey="results",
#
# TigerGraphException: ('Failed to convert sdg vertex id for parameter inName', 'GSQL-2500')

# %%
##getting this error... ('Failed to convert sdg vertex id for parameter inName', 'GSQL-2500'),
#tg folks said try this weird syntax instead params='inName='+ inputName ... still getting same error

inputName = "clean"

conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_toasia(VERTEX<sdg> inName) FOR GRAPH exp5 SYNTAX v2 {
    
    start = {inName};
    result = SELECT d FROM start:s - () - docs:d - () - continents:c; 
    
    PRINT result;
}
""", 
    params='inName='+ inputName 
)
# Out:
# ---------------------------------------------------------------------------
# TigerGraphException                       Traceback (most recent call last)
# <ipython-input-29-da470e8ea936> in <module>()
#      13 }
#      14 """,
# ---> 15     params='inName='+ inputName
#      16 )
#      17
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in runInterpretedQuery(self, queryText, params)
#    1193         """
#    1194         queryText = queryText.replace("$graphname", self.graphname)
# -> 1195         return self._post(self.gsUrl + "/gsqlserver/interpreted_query", data=queryText, params=params, authMode="pwd")
#    1196
#    1197     # Pandas DataFrame support =================================================
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in _post(self, url, authMode, headers, data, resKey, skipCheck, params)
#     220         For argument details, see `_req`.
#     221         """
# --> 222         return self._req("POST", url, authMode, headers, data, resKey, skipCheck, params)
#     223
#     224     def _delete(self, url, authMode="token"):
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in _req(self, method, url, authMode, headers, data, resKey, skipCheck, params)
#     198         res = json.loads(res.text)
#     199         if not skipCheck:
# --> 200             self._errorCheck(res)
#     201         if not resKey:
#     202             if self.debug:
#
# /usr/local/lib/python3.7/dist-packages/pyTigerGraph/pyTigerGraph.py in _errorCheck(self, res)
#     142         if "error" in res and res["error"] and res["error"] != "false":
#     143             # Endpoint might return string "false" rather than Boolean false
# --> 144             raise TigerGraphException(res["message"], (res["code"] if "code" in res else None))
#     145
#     146     def _req(self, method, url, authMode="token", headers=None, data=None, resKey="results",
#
# TigerGraphException: ('Failed to convert sdg vertex id for parameter inName', 'GSQL-2500')

# %%
#no luck... then they said to:
#use vertex id or use where clause instead of the vertex string... (or try as installed query)
#im going to first try removing the variable,

inputName = 6

conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_toasia(VERTEX<sdg> inName) FOR GRAPH exp5 SYNTAX v2 {
    
    start = {inName};
    result = SELECT d FROM start:s - () - docs:d - () - continents:c; 
    
    PRINT result;
}
""", 
    params={ "inName": inputName }
)

#ok, it works, but not sure if it is what i wanted!
# Out:
# [{'result': [{'attributes': {'id': 9,
#      'page': 2,
#      'txt': 'C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence'},
#     'v_id': '9',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3920,
#      'txt': 'Final Government Distribution Glossary IPCC AR6 WGI 1 2 Latent heat flux The turbulent flux of heat from the Earths surface to the atmosphere that is associated 3 with evaporation or condensation of water vapour at the surface a component of the surface energy budget 4 See also Atmosphere and Flux 5 6 Lifetime Lifetime is a general term used for various time scales characterizing the rate of processes 7 affecting the concentration of trace gases The following lifetimes may be distinguished 8 9 Response time or adjustment time Ta Response time or adjustment time Ta is the time scale 10 characterizing the decay of an instantaneous pulse input into the reservoir The term adjustment time is also 11 used to characterize the adjustment of the mass of a reservoir following a step change in the source strength 12 Halflife or decay constant is used to quantify a firstorder exponential decay process See Response time or 13 adjustment time for a different definition pertinent to climate variations 14 ED N S 15 The term lifetime is sometimes used for simplicity as a surrogate for adjustment time 16 IT AL IO 17 In simple cases where the global removal of the compound is directly proportional to the total mass of the 18 reservoir the adjustment time equals the turnover time T = Ta An example is CFC11 which is removed 19 from the atmosphere only by photochemical processes in the stratosphere In more complicated cases where N S 20 several reservoirs are involved or where the removal is not proportional to the total mass the equality T = Ta 21 no longer holds 22 23 FI R Carbon dioxide CO2 is an extreme example Its turnover time is only about 4 years because of the rapid VE 24 exchange between the atmosphere and the ocean and terrestrial biota However a large part of that CO2 is 25 returned to the atmosphere within a few years The adjustment time of CO2 in the atmosphere is determined 26 from the rates of removal of carbon by a range of processes with timescales from months to hundreds of 27 thousands of years As a result 15 to 40 of an emitted CO2 pulse will remain in the atmosphere longer than 28 1000 years 10 to 25 will remain about ten thousand years and the rest will be removed over several TO D 29 hundred thousand years 30 T E 31 In the case of methane CH4 the adjustment time is different from the turnover time because the removal is 32 mainly through a chemical reaction with the hydroxyl radical OH the concentration of which itself T 33 depends on the CH4 concentration Therefore the CH4 removal rate S is not proportional to its total mass M EC P 34 35 Turnover time T also called global atmospheric lifetime is the ratio of the mass M of a reservoir eg a BJ CE 36 gaseous compound in the atmosphere and the total rate of removal S from the reservoir T = MS For each 37 removal process separate turnover times can be defined In soil carbon biology this is referred to as Mean 38 Residence Time 39 SU AC 40 Lightabsorbing particles Lightabsorbing particles LAP eg black carbon brown carbon dust are 41 particles that absorb solar radiation and convert it into internal energy thus raising the particles temperature 42 and emitting thermalinfrared radiation that is selectively absorbed by the surrounding medium LAP affect 43 the energy balance of the atmosphere clouds and when deposited on snow and ice they reduce snowice 44 albedo increasing heating and accelerating smelting These particles have a warming effect on climate 45 46 Likelihood The chance of a specific outcome occurring where this might be estimated probabilistically 47 Likelihood is expressed in this report using a standard terminology Mastrandrea et al 2010 See also 48 Agreement Confidence Evidence and Uncertainty 49 50 Lithosphere The upper layer of the solid Earth both continental and oceanic which comprises all crustal 51 rocks and the cold mainly elastic part of the uppermost mantle Volcanic activity although part of the 52 lithosphere is not considered as part of the cl ...
#     'v_id': '8',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': 'WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '3',
#     'v_type': 'docs'}]}]

# %%
inputName = 6

conn.runInterpretedQuery("""
INTERPRET QUERY sdg_todoc_toasia(VERTEX<sdg> inName) FOR GRAPH exp5 SYNTAX v2 {
    
    start = {inName};
    result = SELECT d FROM start:s - () - docs:d - () - continents:c WHERE c.cont == "oceania"; 
    
    PRINT result;
}
""", 
    params={ "inName": inputName }
)
# Out:
# [{'result': [{'attributes': {'id': 5,
#      'page': 68,
#      'txt': '<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 9,
#      'page': 2,
#      'txt': 'C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence'},
#     'v_id': '9',
#     'v_type': 'docs'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '4',
#     'v_type': 'docs'}]}]

# %%
#lets try to install it and see what happens (what it looks like in studio)
conn.gsql("""
USE GRAPH exp5
CREATE QUERY sdg_todoc_toasia(VERTEX<sdg> 6) FOR GRAPH exp5 SYNTAX v2 {
    start = {6};
    result = SELECT d FROM start:s - () - docs:d - () - continents:c; 
    
    PRINT result;
} 
""")
# Out:
# "Using graph 'exp5'\nline 3:42 mismatched input '6' expecting {ABORT, BY, COMMIT, DISTINCT, FILE, GROUP, INSERT, LASTHOP, LIST, LOG, MAP, MATCH, NOW, PATH, PER, REPLACE, SRC, TGT, TO_DATETIME, UPDATE, NAME}\nline 4:13 extraneous input '6' expecting {ABORT, ANY, BY, COMMIT, DISTINCT, FILE, GROUP, INSERT, LASTHOP, LIST, LOG, MAP, MATCH, NOW, PATH, PER, REPLACE, SELECT_VERTEX, SRC, TGT, TO_DATETIME, UPDATE, '}', '_', NAME, GACCNAME}\nParsing encountered 2 syntax error(s)\n\nFailed to create queries: [sdg_todoc_toasia]."

# %%
conn.gsql("""
USE GRAPH exp5
INSTALL QUERY sdg_todoc_toasia
""")

# %% [markdown]
#  #### example3... find all "clean" sdg vertices (#6) are connected to which docs (need to traverse clean to docs) and extract 'weight' attribute from edge, for each doc

# %%
inputName = "climate"
docName = 1

conn.runInterpretedQuery("""
INTERPRET QUERY sdg_weight_sum_int(STRING inName) FOR GRAPH exp5 {

    SumAccum<INT> @@weightsum;  /*declare the accumulator here*/

    start = {sdg.*};
    result = SELECT d FROM start:s  - (reverse_has_sdg:w) - docs:d 
    WHERE s.sdga == inName AND d.id == 1
      ACCUM
        @@weightsum += w.weight;
    
    PRINT @@weightsum as weight_Sum;  
}
""",
    params={ "inName": inputName } 
    #params={ "dName": docName } 
)

#works!! install it! (without variable for now)
# Out:
# [{'weight_Sum': 131}]

# %%
conn.gsql("""
USE GRAPH exp5
CREATE QUERY sdg_weight_sum() FOR GRAPH exp5 {

    SumAccum<INT> @@weightsum;  /*declare the accumulator here*/

    start = {sdg.*};
    result = SELECT d FROM start:s  - (reverse_has_sdg:w) - docs:d 
    WHERE s.sdga == "clean" /*AND d.id == 1*/
      ACCUM
        @@weightsum += w.weight;
    
    PRINT @@weightsum as weight_Sum;  
}
""")
# Out:
# "Using graph 'exp5'\nSemantic Check Fails: The query name sdg_weight_sum is used by another object! Please use a different name.\nFailed to create queries: [sdg_weight_sum]."

# %%
conn.gsql("""
USE GRAPH exp5
INSTALL QUERY sdg_weight_sum
""")
# Out:
# 'Using graph \'exp5\'\nStart installing queries, about 1 minute ...\nsdg_weight_sum query: curl -X GET \'https://127.0.0.1:9000/query/exp5/sdg_weight_sum\'. Add -H "Authorization: Bearer TOKEN" if authentication is enabled.\nSelect \'m1\' as compile server, now connecting ...\nNode \'m1\' is prepared as compile server.\n\nQuery installation finished.'

# %% [markdown]
# #### example4...

# %%
print(tg. __version__)
# Out:
# 0.0.9.9.2

# %%
#whole graph test (i installed this directly in tgstudio as "whole graph" - it works there)
conn.runInterpretedQuery("""
INTERPRET QUERY whole_graph_test() FOR GRAPH exp5 { 
// WHOLE GRAPH:
//  Show it all, including attributes!
  ListAccum <EDGE> @@allE;
  G = {ANY};
    
  G2 = SELECT s FROM G:s-(:e)->:t 
    ACCUM @@allE += e
    HAVING 1==0;
    
  PRINT G, @@allE;
    
}
""")
# Out:
# [{'@@allE': [{'attributes': {'docid': 10,
#      'sdg': '"water"',
#      'sdgid': 14,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9, 'sdg': '"water"', 'sdgid': 14, 'weight': 2399},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sdg': '"water"', 'sdgid': 14, 'weight': 9},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sdg': '"water"', 'sdgid': 14, 'weight': 66},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 1, 'sdg': '"water"', 'sdgid': 14, 'weight': 49},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sdg': '"water"', 'sdgid': 14, 'weight': 87},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sdg': '"water"', 'sdgid': 14, 'weight': 96},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sdg': '"water"', 'sdgid': 14, 'weight': 86},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '14',
#     'from_type': 'sdg',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9, 'sdg': '"cities"', 'sdgid': 11, 'weight': 137},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sdg': '"cities"', 'sdgid': 11, 'weight': 2},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sdg': '"cities"', 'sdgid': 11, 'weight': 25},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 1, 'sdg': '"cities"', 'sdgid': 11, 'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sdg': '"cities"', 'sdgid': 11, 'weight': 4},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sdg': '"cities"', 'sdgid': 11, 'weight': 2},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sdg': '"cities"', 'sdgid': 11, 'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '11',
#     'from_type': 'sdg',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 10, 'sdg': '"climate"', 'sdgid': 13, 'weight': 12},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9,
#      'sdg': '"climate"',
#      'sdgid': 13,
#      'weight': 17802},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sdg': '"climate"', 'sdgid': 13, 'weight': 131},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sdg': '"climate"', 'sdgid': 13, 'weight': 42},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 1, 'sdg': '"climate"', 'sdgid': 13, 'weight': 131},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sdg': '"climate"', 'sdgid': 13, 'weight': 153},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sdg': '"climate"', 'sdgid': 13, 'weight': 120},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sdg': '"climate"', 'sdgid': 13, 'weight': 154},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '13',
#     'from_type': 'sdg',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 10, 'sdg': '"land"', 'sdgid': 15, 'weight': 2},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9, 'sdg': '"land"', 'sdgid': 15, 'weight': 3341},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sdg': '"land"', 'sdgid': 15, 'weight': 73},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sdg': '"land"', 'sdgid': 15, 'weight': 49},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 1, 'sdg': '"land"', 'sdgid': 15, 'weight': 47},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sdg': '"land"', 'sdgid': 15, 'weight': 29},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sdg': '"land"', 'sdgid': 15, 'weight': 35},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sdg': '"land"', 'sdgid': 15, 'weight': 31},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '15',
#     'from_type': 'sdg',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 10, 'sdg': '"water"', 'sdgid': 14, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '14',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 10, 'sdg': '"climate"', 'sdgid': 13, 'weight': 12},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '13',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 10, 'sdg': '"land"', 'sdgid': 15, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '15',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 10, 'sentiment': '"anticipation"', 'totcount': 7},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"trust"', 'totcount': 19},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"sadness"', 'totcount': 2},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"anger"', 'totcount': 2},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"joy"', 'totcount': 4},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"fear"', 'totcount': 6},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"disgust"', 'totcount': 5},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 10, 'sentiment': '"surprise"', 'totcount': 10},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sentiment'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 10,
#      'weight': 2},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 2,
#      'continent': '"asia"',
#      'docid': 10,
#      'weight': 1146},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 6,
#      'continent': '"america"',
#      'docid': 10,
#      'weight': 1968},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 10,
#      'weight': 978},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 10,
#      'weight': 783},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 3,
#      'continent': '"antarctica"',
#      'docid': 10,
#      'weight': 362},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '10',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'continents'},
#    {'attributes': {'docid': 9,
#      'sdg': '"inequalities"',
#      'sdgid': 10,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '10',
#     'from_type': 'sdg',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8,
#      'sdg': '"inequalities"',
#      'sdgid': 10,
#      'weight': 15},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '10',
#     'from_type': 'sdg',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5,
#      'sdg': '"inequalities"',
#      'sdgid': 10,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '10',
#     'from_type': 'sdg',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9, 'sdg': '"water"', 'sdgid': 14, 'weight': 2399},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '14',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"cities"', 'sdgid': 11, 'weight': 137},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '11',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9,
#      'sdg': '"climate"',
#      'sdgid': 13,
#      'weight': 17802},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '13',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"land"', 'sdgid': 15, 'weight': 3341},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '15',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9,
#      'sdg': '"inequalities"',
#      'sdgid': 10,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '10',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"industry"', 'sdgid': 9, 'weight': 55},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"hunger"', 'sdgid': 2, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"peace"', 'sdgid': 16, 'weight': 3},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '16',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"work"', 'sdgid': 8, 'weight': 318},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"poverty"', 'sdgid': 1, 'weight': 10},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"clean"', 'sdgid': 6, 'weight': 22},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"gender"', 'sdgid': 5, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"education"', 'sdgid': 4, 'weight': 6},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"health"', 'sdgid': 3, 'weight': 219},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9,
#      'sdg': '"consumption"',
#      'sdgid': 12,
#      'weight': 38},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '12',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9, 'sdg': '"energy"', 'sdgid': 7, 'weight': 1115},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 9,
#      'sentiment': '"anticipation"',
#      'totcount': 15694},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"trust"', 'totcount': 26762},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"sadness"', 'totcount': 7747},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"anger"', 'totcount': 5100},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"joy"', 'totcount': 6674},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"fear"', 'totcount': 15959},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"disgust"', 'totcount': 3521},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 9, 'sentiment': '"surprise"', 'totcount': 10520},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sentiment'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 9,
#      'weight': 30},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 6,
#      'continent': '"america"',
#      'docid': 9,
#      'weight': 93},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 1,
#      'continent': '"africa"',
#      'docid': 9,
#      'weight': 1113},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 9,
#      'weight': 48},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 9,
#      'weight': 47},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '9',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'continents'},
#    {'attributes': {'docid': 9, 'sdg': '"industry"', 'sdgid': 9, 'weight': 55},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '9',
#     'from_type': 'sdg',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sdg': '"industry"', 'sdgid': 9, 'weight': 7},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '9',
#     'from_type': 'sdg',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sdg': '"industry"', 'sdgid': 9, 'weight': 2},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '9',
#     'from_type': 'sdg',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sdg': '"industry"', 'sdgid': 9, 'weight': 6},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '9',
#     'from_type': 'sdg',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sdg': '"industry"', 'sdgid': 9, 'weight': 6},
#     'directed': True,
#     'e_type': 'reverse_has_sdg',
#     'from_id': '9',
#     'from_type': 'sdg',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 10,
#      'weight': 2},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '9',
#     'from_type': 'continents',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 9,
#      'weight': 30},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '9',
#     'from_type': 'continents',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 2,
#      'weight': 3},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '9',
#     'from_type': 'continents',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 5,
#      'weight': 7},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '9',
#     'from_type': 'continents',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 4,
#      'weight': 9},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '9',
#     'from_type': 'continents',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 7,
#      'weight': 5},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '9',
#     'from_type': 'continents',
#     'to_id': '7',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sdg': '"water"', 'sdgid': 14, 'weight': 9},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '14',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"cities"', 'sdgid': 11, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '11',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"climate"', 'sdgid': 13, 'weight': 131},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '13',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"land"', 'sdgid': 15, 'weight': 73},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '15',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"work"', 'sdgid': 8, 'weight': 10},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"poverty"', 'sdgid': 1, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"health"', 'sdgid': 3, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sdg': '"energy"', 'sdgid': 7, 'weight': 4},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 2, 'sentiment': '"anticipation"', 'totcount': 83},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"trust"', 'totcount': 230},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"sadness"', 'totcount': 51},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"anger"', 'totcount': 46},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"joy"', 'totcount': 61},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"fear"', 'totcount': 106},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"disgust"', 'totcount': 39},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 2, 'sentiment': '"surprise"', 'totcount': 60},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sentiment'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 2,
#      'weight': 3},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 2,
#      'continent': '"asia"',
#      'docid': 2,
#      'weight': 16},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 6,
#      'continent': '"america"',
#      'docid': 2,
#      'weight': 56},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 1,
#      'continent': '"africa"',
#      'docid': 2,
#      'weight': 22},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 2,
#      'weight': 14},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 2,
#      'weight': 12},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 3,
#      'continent': '"antarctica"',
#      'docid': 2,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '2',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'continents'},
#    {'attributes': {'docid': 8, 'sdg': '"water"', 'sdgid': 14, 'weight': 66},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '14',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"cities"', 'sdgid': 11, 'weight': 25},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '11',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"climate"', 'sdgid': 13, 'weight': 42},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '13',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"land"', 'sdgid': 15, 'weight': 49},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '15',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8,
#      'sdg': '"inequalities"',
#      'sdgid': 10,
#      'weight': 15},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '10',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"industry"', 'sdgid': 9, 'weight': 7},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"hunger"', 'sdgid': 2, 'weight': 17},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"peace"', 'sdgid': 16, 'weight': 6},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '16',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"work"', 'sdgid': 8, 'weight': 26},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"poverty"', 'sdgid': 1, 'weight': 50},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"clean"', 'sdgid': 6, 'weight': 14},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"gender"', 'sdgid': 5, 'weight': 26},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"education"', 'sdgid': 4, 'weight': 29},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"health"', 'sdgid': 3, 'weight': 98},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8,
#      'sdg': '"consumption"',
#      'sdgid': 12,
#      'weight': 27},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '12',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sdg': '"energy"', 'sdgid': 7, 'weight': 60},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 8, 'sentiment': '"anticipation"', 'totcount': 506},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"trust"', 'totcount': 732},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"sadness"', 'totcount': 407},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"anger"', 'totcount': 255},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"joy"', 'totcount': 349},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"fear"', 'totcount': 463},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"disgust"', 'totcount': 175},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 8, 'sentiment': '"surprise"', 'totcount': 138},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sentiment'},
#    {'attributes': {'contid': 2,
#      'continent': '"asia"',
#      'docid': 8,
#      'weight': 136},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 6,
#      'continent': '"america"',
#      'docid': 8,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 1,
#      'continent': '"africa"',
#      'docid': 8,
#      'weight': 114},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '8',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'continents'},
#    {'attributes': {'docid': 1, 'sdg': '"water"', 'sdgid': 14, 'weight': 49},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '14',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"cities"', 'sdgid': 11, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '11',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"climate"', 'sdgid': 13, 'weight': 131},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '13',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"land"', 'sdgid': 15, 'weight': 47},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '15',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"hunger"', 'sdgid': 2, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"peace"', 'sdgid': 16, 'weight': 4},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '16',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"work"', 'sdgid': 8, 'weight': 62},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"poverty"', 'sdgid': 1, 'weight': 5},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"clean"', 'sdgid': 6, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"gender"', 'sdgid': 5, 'weight': 46},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"education"', 'sdgid': 4, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"health"', 'sdgid': 3, 'weight': 8},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1,
#      'sdg': '"consumption"',
#      'sdgid': 12,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '12',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sdg': '"energy"', 'sdgid': 7, 'weight': 8},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 1, 'sentiment': '"anticipation"', 'totcount': 316},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"trust"', 'totcount': 794},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"sadness"', 'totcount': 59},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"anger"', 'totcount': 68},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"joy"', 'totcount': 195},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"fear"', 'totcount': 165},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"disgust"', 'totcount': 75},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 1, 'sentiment': '"surprise"', 'totcount': 62},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sentiment'},
#    {'attributes': {'contid': 2,
#      'continent': '"asia"',
#      'docid': 1,
#      'weight': 18},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 6,
#      'continent': '"america"',
#      'docid': 1,
#      'weight': 18},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 1,
#      'continent': '"africa"',
#      'docid': 1,
#      'weight': 20},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 1,
#      'weight': 18},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 1,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 3,
#      'continent': '"antarctica"',
#      'docid': 1,
#      'weight': 3},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '1',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'continents'},
#    {'attributes': {'docid': 5, 'sdg': '"water"', 'sdgid': 14, 'weight': 87},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '14',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"cities"', 'sdgid': 11, 'weight': 4},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '11',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"climate"', 'sdgid': 13, 'weight': 153},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '13',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"land"', 'sdgid': 15, 'weight': 29},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '15',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5,
#      'sdg': '"inequalities"',
#      'sdgid': 10,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '10',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"industry"', 'sdgid': 9, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"hunger"', 'sdgid': 2, 'weight': 1},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"peace"', 'sdgid': 16, 'weight': 4},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '16',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"work"', 'sdgid': 8, 'weight': 69},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"poverty"', 'sdgid': 1, 'weight': 2},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"clean"', 'sdgid': 6, 'weight': 3},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"gender"', 'sdgid': 5, 'weight': 76},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"education"', 'sdgid': 4, 'weight': 7},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"health"', 'sdgid': 3, 'weight': 12},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5,
#      'sdg': '"consumption"',
#      'sdgid': 12,
#      'weight': 5},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '12',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sdg': '"energy"', 'sdgid': 7, 'weight': 10},
#     'directed': True,
#     'e_type': 'has_sdg',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sdg'},
#    {'attributes': {'docid': 5, 'sentiment': '"anticipation"', 'totcount': 358},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"trust"', 'totcount': 1035},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '8',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"sadness"', 'totcount': 86},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"anger"', 'totcount': 85},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"joy"', 'totcount': 227},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '5',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"fear"', 'totcount': 224},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"disgust"', 'totcount': 60},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '3',
#     'to_type': 'sentiment'},
#    {'attributes': {'docid': 5, 'sentiment': '"surprise"', 'totcount': 76},
#     'directed': True,
#     'e_type': 'has_sentiment',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '7',
#     'to_type': 'sentiment'},
#    {'attributes': {'contid': 9,
#      'continent': '"oceania"',
#      'docid': 5,
#      'weight': 7},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '9',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 2,
#      'continent': '"asia"',
#      'docid': 5,
#      'weight': 31},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '2',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 6,
#      'continent': '"america"',
#      'docid': 5,
#      'weight': 16},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '6',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 1,
#      'continent': '"africa"',
#      'docid': 5,
#      'weight': 27},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '1',
#     'to_type': 'continents'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 5,
#      'weight': 2},
#     'directed': True,
#     'e_type': 'has_continent',
#     'from_id': '5',
#     'from_type': 'docs',
#     'to_id': '4',
#     'to_type': 'continents'},
#    {'attributes': {'docid': 10, 'sentiment': '"anticipation"', 'totcount': 7},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9,
#      'sentiment': '"anticipation"',
#      'totcount': 15694},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sentiment': '"anticipation"', 'totcount': 83},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sentiment': '"anticipation"', 'totcount': 506},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 1, 'sentiment': '"anticipation"', 'totcount': 316},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sentiment': '"anticipation"', 'totcount': 358},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sentiment': '"anticipation"', 'totcount': 342},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sentiment': '"anticipation"', 'totcount': 324},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 7, 'sentiment': '"anticipation"', 'totcount': 0},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '2',
#     'from_type': 'sentiment',
#     'to_id': '7',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 10, 'sentiment': '"trust"', 'totcount': 19},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 9, 'sentiment': '"trust"', 'totcount': 26762},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 2, 'sentiment': '"trust"', 'totcount': 230},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 8, 'sentiment': '"trust"', 'totcount': 732},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '8',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 1, 'sentiment': '"trust"', 'totcount': 794},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 5, 'sentiment': '"trust"', 'totcount': 1035},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 4, 'sentiment': '"trust"', 'totcount': 975},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
#     'from_type': 'sentiment',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'docid': 3, 'sentiment': '"trust"', 'totcount': 894},
#     'directed': True,
#     'e_type': 'reverse_has_sentiment',
#     'from_id': '8',
# ...
#      'continent': '"europe"',
#      'docid': 1,
#      'weight': 18},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '5',
#     'from_type': 'continents',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 4,
#      'weight': 21},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '5',
#     'from_type': 'continents',
#     'to_id': '4',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 3,
#      'weight': 18},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '5',
#     'from_type': 'continents',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 5,
#      'continent': '"europe"',
#      'docid': 7,
#      'weight': 17},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '5',
#     'from_type': 'continents',
#     'to_id': '7',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 10,
#      'weight': 783},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '4',
#     'from_type': 'continents',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 9,
#      'weight': 47},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '4',
#     'from_type': 'continents',
#     'to_id': '9',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 2,
#      'weight': 12},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '4',
#     'from_type': 'continents',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 1,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '4',
#     'from_type': 'continents',
#     'to_id': '1',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 5,
#      'weight': 2},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '4',
#     'from_type': 'continents',
#     'to_id': '5',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 4,
#      'continent': '"australia"',
#      'docid': 3,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '4',
#     'from_type': 'continents',
#     'to_id': '3',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 3,
#      'continent': '"antarctica"',
#      'docid': 10,
#      'weight': 362},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '3',
#     'from_type': 'continents',
#     'to_id': '10',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 3,
#      'continent': '"antarctica"',
#      'docid': 2,
#      'weight': 1},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '3',
#     'from_type': 'continents',
#     'to_id': '2',
#     'to_type': 'docs'},
#    {'attributes': {'contid': 3,
#      'continent': '"antarctica"',
#      'docid': 1,
#      'weight': 3},
#     'directed': True,
#     'e_type': 'reverse_has_continent',
#     'from_id': '3',
#     'from_type': 'continents',
#     'to_id': '1',
#     'to_type': 'docs'}],
#   'G': [{'attributes': {'id': 11, 'sdga': 'cities'},
#     'v_id': '11',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 13, 'sdga': 'climate'},
#     'v_id': '13',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 14, 'sdga': 'water'}, 'v_id': '14', 'v_type': 'sdg'},
#    {'attributes': {'id': 10, 'page': 40, 'txt': 'NA'},
#     'v_id': '10',
#     'v_type': 'docs'},
#    {'attributes': {'id': 10, 'sdga': 'inequalities'},
#     'v_id': '10',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 9,
#      'page': 2,
#      'txt': 'C Climate Information for Risk Assessment and Regional Adaptation C1 Natural drivers and internal variability will modulate humancaused changes especially at regional scales and in the near term with little effect on centennial global warming These modulations are important to consider in planning for the full range of possible changes C2 With further global warming every region is projected to increasingly experience concurrent and multiple changes in climatic impactdrivers Changes in several climatic impactdrivers would be more widespread at 2<U+00B0>C compared to 15<U+00B0>C global warming and even more widespread andor pronounced for higher warming levels C3 Lowlikelihood outcomes such as ice sheet collapse abrupt ocean circulation changes some compound extreme events and warming substantially larger than the assessed very likely range of future warming cannot be ruled out and are part of risk assessment D Limiting Future Climate Change D1 From a physical science perspective limiting humaninduced global warming to a specific level requires limiting cumulative CO2 emissions reaching at least net zero CO2 emissions along with strong reductions in other greenhouse gas emissions Strong rapid and sustained reductions in CH4 emissions would also limit the warming effect resulting from declining aerosol pollution and would improve air quality D2 Scenarios with low or very low greenhouse gas GHG emissions SSP119 and SSP1 26 lead within years to discernible effects on greenhouse gas and aerosol concentrations and air quality relative to high and very high GHG emissions scenarios SSP370 or SSP585 Under these contrasting scenarios discernible differences in trends of global surface temperature would begin to emerge from natural variability within around 20 years and over longer time periods for many other climatic impactdrivers high confidence'},
#     'v_id': '9',
#     'v_type': 'docs'},
#    {'attributes': {'id': 9, 'sdga': 'industry'}, 'v_id': '9', 'v_type': 'sdg'},
#    {'attributes': {'cont': 'oceania', 'id': 9},
#     'v_id': '9',
#     'v_type': 'continents'},
#    {'attributes': {'id': 2,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '2',
#     'v_type': 'docs'},
#    {'attributes': {'id': 8,
#      'page': 3920,
#      'txt': 'Final Government Distribution Glossary IPCC AR6 WGI 1 2 Latent heat flux The turbulent flux of heat from the Earths surface to the atmosphere that is associated 3 with evaporation or condensation of water vapour at the surface a component of the surface energy budget 4 See also Atmosphere and Flux 5 6 Lifetime Lifetime is a general term used for various time scales characterizing the rate of processes 7 affecting the concentration of trace gases The following lifetimes may be distinguished 8 9 Response time or adjustment time Ta Response time or adjustment time Ta is the time scale 10 characterizing the decay of an instantaneous pulse input into the reservoir The term adjustment time is also 11 used to characterize the adjustment of the mass of a reservoir following a step change in the source strength 12 Halflife or decay constant is used to quantify a firstorder exponential decay process See Response time or 13 adjustment time for a different definition pertinent to climate variations 14 ED N S 15 The term lifetime is sometimes used for simplicity as a surrogate for adjustment time 16 IT AL IO 17 In simple cases where the global removal of the compound is directly proportional to the total mass of the 18 reservoir the adjustment time equals the turnover time T = Ta An example is CFC11 which is removed 19 from the atmosphere only by photochemical processes in the stratosphere In more complicated cases where N S 20 several reservoirs are involved or where the removal is not proportional to the total mass the equality T = Ta 21 no longer holds 22 23 FI R Carbon dioxide CO2 is an extreme example Its turnover time is only about 4 years because of the rapid VE 24 exchange between the atmosphere and the ocean and terrestrial biota However a large part of that CO2 is 25 returned to the atmosphere within a few years The adjustment time of CO2 in the atmosphere is determined 26 from the rates of removal of carbon by a range of processes with timescales from months to hundreds of 27 thousands of years As a result 15 to 40 of an emitted CO2 pulse will remain in the atmosphere longer than 28 1000 years 10 to 25 will remain about ten thousand years and the rest will be removed over several TO D 29 hundred thousand years 30 T E 31 In the case of methane CH4 the adjustment time is different from the turnover time because the removal is 32 mainly through a chemical reaction with the hydroxyl radical OH the concentration of which itself T 33 depends on the CH4 concentration Therefore the CH4 removal rate S is not proportional to its total mass M EC P 34 35 Turnover time T also called global atmospheric lifetime is the ratio of the mass M of a reservoir eg a BJ CE 36 gaseous compound in the atmosphere and the total rate of removal S from the reservoir T = MS For each 37 removal process separate turnover times can be defined In soil carbon biology this is referred to as Mean 38 Residence Time 39 SU AC 40 Lightabsorbing particles Lightabsorbing particles LAP eg black carbon brown carbon dust are 41 particles that absorb solar radiation and convert it into internal energy thus raising the particles temperature 42 and emitting thermalinfrared radiation that is selectively absorbed by the surrounding medium LAP affect 43 the energy balance of the atmosphere clouds and when deposited on snow and ice they reduce snowice 44 albedo increasing heating and accelerating smelting These particles have a warming effect on climate 45 46 Likelihood The chance of a specific outcome occurring where this might be estimated probabilistically 47 Likelihood is expressed in this report using a standard terminology Mastrandrea et al 2010 See also 48 Agreement Confidence Evidence and Uncertainty 49 50 Lithosphere The upper layer of the solid Earth both continental and oceanic which comprises all crustal 51 rocks and the cold mainly elastic part of the uppermost mantle Volcanic activity although part of the 52 lithosphere is not considered as part of the cl ...
#     'v_id': '8',
#     'v_type': 'docs'},
#    {'attributes': {'id': 1,
#      'page': 52,
#      'txt': 'WORKING FOR A JUST WORLD THAT VALUES AND CONSERVES NATURE INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland mailiucnorg Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '1',
#     'v_type': 'docs'},
#    {'attributes': {'id': 6,
#      'page': 68,
#      'txt': 'Les objectifs de d<e9>veloppement durable sont aujourdhui plus importants que jamais Le temps est <e0> pr<e9>sent venu dassurer le bien <ea>tre des peuples des <e9>conomies des soci<e9>t<e9>s et de notre plan<e8>te Ant<f3>nio GUTERRES Secr<e9>taire g<e9>n<e9>ral de lONU 2104310'},
#     'v_id': '6',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5,
#      'page': 68,
#      'txt': '<U+202B><U+0623><U+0635><U+0628><U+062D><U+062A> <U+0623><U+0647><U+062F><U+0627><U+0641> <U+0627><U+0644><U+062A><U+0646><U+0645><U+064A><U+0629> <U+0627><U+0645><U+0644><U+0633><U+062A><U+062F><U+0627><U+0645><U+0629> <U+0623><U+0643><U+062B><U+0631><U+202C> <U+202B><U+0623><U+0647><U+0645><U+064A><U+0629> <U+0627><U+0644><U+064A><U+0648><U+0645> <U+0645><U+0646> <U+0623><U+064A> <U+0648><U+0642><U+062A> <U+0645><U+0649><U+0636><U+202A> <U+202C><U+0641><U+0642><U+062F> <U+062D><U+0627><U+0646><U+202C> <U+202B><U+0627><U+0644><U+0648><U+0642><U+062A> <U+0627><U+0622><U+0644><U+0646> <U+0644><U+062A><U+0623><U+0645><U+0646><U+064A> <U+0631><U+0641><U+0627><U+0647> <U+0627><U+0644><U+0646><U+0627><U+0633> <U+0648><U+0627><U+0627><U+0644><U+0642><U+062A><U+0635><U+0627><U+062F><U+0627><U+062A><U+202C> <U+202B><U+0648><U+0627><U+0645><U+0644><U+062C><U+062A><U+0645><U+0639><U+0627><U+062A> <U+0648><U+0643><U+0648><U+0643><U+0628><U+0646><U+0627> <U+0647><U+0630><U+0627><U+202A><U+202C><U+202C> <U+202B> <U+0623><U+0646><U+0637><U+0648><U+0646><U+064A><U+0648> <U+063A><U+0648><U+062A><U+0631><U+064A><U+064A><U+0634><U+202C> <U+202B><U+0627><U+0623><U+0644><U+0645><U+0646><U+064A> <U+0627><U+0644><U+0639><U+0627><U+0645> <U+0644><U+0623><U+0644><U+0645><U+0640><U+0645> <U+0627><U+0645><U+0644><U+062A><U+062D><U+0640><U+062F><U+0629><U+202C> <U+202B><U+202A>2104310<U+202C><U+202C>'},
#     'v_id': '5',
#     'v_type': 'docs'},
#    {'attributes': {'id': 2, 'senti': 'anticipation'},
#     'v_id': '2',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 8, 'senti': 'trust'},
#     'v_id': '8',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 4,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '4',
#     'v_type': 'docs'},
#    {'attributes': {'id': 6, 'senti': 'sadness'},
#     'v_id': '6',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 1, 'senti': 'anger'},
#     'v_id': '1',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 3,
#      'page': 52,
#      'txt': 'working for a just world that values and conserves nature INTERNATIONAL UNION FOR CONSERVATION OF NATURE WORLD HEADQUARTERS Rue Mauverney 28 1196 Gland Switzerland Tel +41 22 999 0000 Fax +41 22 999 0002 wwwiucnorg twittercomiucn facebookcomiucnorg'},
#     'v_id': '3',
#     'v_type': 'docs'},
#    {'attributes': {'id': 7,
#      'page': 68,
#      'txt': 'The Sustainable Development Goals are more important now than ever Now is the time to secure the wellbeing of people economies societies and our planet Ant<f3>nio GUTERRES SecretaryGeneral of the United Nations ISBN 9789211014396 2104310'},
#     'v_id': '7',
#     'v_type': 'docs'},
#    {'attributes': {'id': 5, 'senti': 'joy'},
#     'v_id': '5',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 2, 'sdga': 'hunger'}, 'v_id': '2', 'v_type': 'sdg'},
#    {'attributes': {'id': 16, 'sdga': 'peace'}, 'v_id': '16', 'v_type': 'sdg'},
#    {'attributes': {'id': 8, 'sdga': 'work'}, 'v_id': '8', 'v_type': 'sdg'},
#    {'attributes': {'id': 4, 'senti': 'fear'},
#     'v_id': '4',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 1, 'sdga': 'poverty'}, 'v_id': '1', 'v_type': 'sdg'},
#    {'attributes': {'id': 6, 'sdga': 'clean'}, 'v_id': '6', 'v_type': 'sdg'},
#    {'attributes': {'id': 3, 'senti': 'disgust'},
#     'v_id': '3',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 7, 'senti': 'surprise'},
#     'v_id': '7',
#     'v_type': 'sentiment'},
#    {'attributes': {'id': 5, 'sdga': 'gender'}, 'v_id': '5', 'v_type': 'sdg'},
#    {'attributes': {'cont': 'asia', 'id': 2},
#     'v_id': '2',
#     'v_type': 'continents'},
#    {'attributes': {'cont': 'south america', 'id': 8},
#     'v_id': '8',
#     'v_type': 'continents'},
#    {'attributes': {'id': 4, 'sdga': 'education'},
#     'v_id': '4',
#     'v_type': 'sdg'},
#    {'attributes': {'cont': 'america', 'id': 6},
#     'v_id': '6',
#     'v_type': 'continents'},
#    {'attributes': {'cont': 'africa', 'id': 1},
#     'v_id': '1',
#     'v_type': 'continents'},
#    {'attributes': {'id': 3, 'sdga': 'health'}, 'v_id': '3', 'v_type': 'sdg'},
#    {'attributes': {'id': 12, 'sdga': 'consumption'},
#     'v_id': '12',
#     'v_type': 'sdg'},
#    {'attributes': {'id': 7, 'sdga': 'energy'}, 'v_id': '7', 'v_type': 'sdg'},
#    {'attributes': {'cont': 'europe', 'id': 5},
#     'v_id': '5',
#     'v_type': 'continents'},
#    {'attributes': {'cont': 'australia', 'id': 4},
#     'v_id': '4',
#     'v_type': 'continents'},
#    {'attributes': {'cont': 'antarctica', 'id': 3},
#     'v_id': '3',
#     'v_type': 'continents'},
#    {'attributes': {'cont': 'north america', 'id': 7},
#     'v_id': '7',
#     'v_type': 'continents'},
#    {'attributes': {'id': 15, 'sdga': 'land'}, 'v_id': '15', 'v_type': 'sdg'}]}]

# %%
#------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------#
#----------------------------------------old errors----------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------#

# %%
results = conn.gsql('''
  USE GRAPH exp3
  CREATE QUERY sdg_from_doc(VERTEX<docs> inDoc) FOR GRAPH exp3 SYNTAX v2 { 
  
  doc = {inDoc};

  tag = SELECT t FROM doc:pe - (has_sdg>) - sdg:p - (has_sdg>) - sdg:t;

  // Below line does the same thing and looks cleaner, intermediate nodes can be ignored if not being referenced
  // tag = SELECT t FROM person:pe - (posted>.has_tag>) - Hashtag:t;

  PRINT tag;
  }
  ''')
print(results)
# Out:
# Using graph 'exp3'
# Warning in query sdg_from_doc (WARN-2): line 7, col 50
# unsatisfiable pattern - (has_sdg>) - sdg:t
# Warning in query sdg_from_doc (WARN-2): line 7, col 22
# unsatisfiable pattern doc:pe - (has_sdg>) - sdg:p - (has_sdg>) - sdg:t
#
# Type Check Error in query sdg_from_doc (TYP-8005): line 7, col 17
# unsatisfiable FROM pattern, query result always empty
#
# Failed to create queries: [sdg_from_doc].
